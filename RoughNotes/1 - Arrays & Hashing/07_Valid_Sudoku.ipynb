# %% [markdown]
# # Valid Sudoku (LeetCode 36)

# %% [markdown]
# ## Notes

# %%
board = [["1","2",".",".","3",".",".",".","."],
 ["4",".",".","5",".",".",".",".","."],
 [".","9","8",".",".",".",".",".","3"],
 ["5",".",".",".","6",".",".",".","4"],
 [".",".",".","8",".","3",".",".","5"],
 ["7",".",".",".","2",".",".",".","6"],
 [".",".",".",".",".",".","2",".","."],
 [".",".",".","4","1","9",".",".","8"],
 [".",".",".",".","8",".",".","7","9"]]

# %%
board = [["1","2",".",".","3",".",".",".","."],
 ["4",".",".","5",".",".",".",".","."],
 [".","9","1",".",".",".",".",".","3"],
 ["5",".",".",".","6",".",".",".","4"],
 [".",".",".","8",".","3",".",".","5"],
 ["7",".",".",".","2",".",".",".","6"],
 [".",".",".",".",".",".","2",".","."],
 [".",".",".","4","1","9",".",".","8"],
 [".",".",".",".","8",".",".","7","9"]]

# %%
for row in board:
    row_clean = [num for num in row if num != "."]
    print(row_clean)
    if len(row_clean) != len(set(row_clean)):
        print(False)
# Out:
# ['1', '2', '3']
# ['4', '5']
# ['9', '1', '3']
# ['5', '6', '4']
# ['8', '3', '5']
# ['7', '2', '6']
# ['2']
# ['4', '1', '9', '8']
# ['8', '7', '9']

# %%
cols = list(map(list, zip(*board)))
print(cols)
# Out:
# [['1', '4', '.', '5', '.', '7', '.', '.', '.'], ['2', '.', '9', '.', '.', '.', '.', '.', '.'], ['.', '.', '1', '.', '.', '.', '.', '.', '.'], ['.', '5', '.', '.', '8', '.', '.', '4', '.'], ['3', '.', '.', '6', '.', '2', '.', '1', '8'], ['.', '.', '.', '.', '3', '.', '.', '9', '.'], ['.', '.', '.', '.', '.', '.', '2', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.', '7'], ['.', '.', '3', '4', '5', '6', '.', '8', '9']]

# %%
for col in cols:
    col_clean = [num for num in col if num != "."]
    print(col_clean)
    if len(col_clean) != len(set(col_clean)):
        print(False)
# Out:
# ['1', '4', '5', '7']
# ['2', '9']
# ['1']
# ['5', '8', '4']
# ['3', '6', '2', '1', '8']
# ['3', '9']
# ['2']
# ['7']
# ['3', '4', '5', '6', '8', '9']

# %%
## 3x3 sub grids
# create hashmap with key (subrow, subcol) and value [list of 9 values]

hashmap = {}

for i in range(len(board)):
    for j in range(len(board[0])):
        hashmap[(i//3, j//3)] = hashmap.get((i//3, j//3), [])
        hashmap[(i//3, j//3)].append(board[i][j])

print(len(hashmap))
print(hashmap)
# Out:
# 9
# {(0, 0): ['1', '2', '.', '4', '.', '.', '.', '9', '1'], (0, 1): ['.', '3', '.', '5', '.', '.', '.', '.', '.'], (0, 2): ['.', '.', '.', '.', '.', '.', '.', '.', '3'], (1, 0): ['5', '.', '.', '.', '.', '.', '7', '.', '.'], (1, 1): ['.', '6', '.', '8', '.', '3', '.', '2', '.'], (1, 2): ['.', '.', '4', '.', '.', '5', '.', '.', '6'], (2, 0): ['.', '.', '.', '.', '.', '.', '.', '.', '.'], (2, 1): ['.', '.', '.', '4', '1', '9', '.', '8', '.'], (2, 2): ['2', '.', '.', '.', '.', '8', '.', '7', '9']}

# %%
for list in hashmap.values():
    clean_list = [num for num in list if num != "."]
    print(clean_list)
    if len(clean_list) != len(set(clean_list)):
        print(False)
# Out:
# ['1', '2', '4', '9', '1']
# False
# ['3', '5']
# ['3']
# ['5', '7']
# ['6', '8', '3', '2']
# ['4', '5', '6']
# []
# ['4', '1', '9', '8']
# ['2', '8', '7', '9']

# %%
def isValidBoard(board):
    for row in board:
        row_clean = [num for num in row if num != "."]
        if len(row_clean) != len(set(row_clean)):
            return False

    cols = list(map(list, zip(*board)))

    for col in cols:
        col_clean = [num for num in col if num != "."]
        if len(col_clean) != len(set(col_clean)):
            return False

    hashmap = {}

    for i in range(len(board)):
        for j in range(len(board[0])):
            hashmap[(i//3, j//3)] = hashmap.get((i//3, j//3), [])
            hashmap[(i//3, j//3)].append(board[i][j])   

    for subgrid in hashmap.values():
        clean_list = [num for num in subgrid if num != "."]
        if len(clean_list) != len(set(clean_list)):
            return False

    return True

# %%
isValidBoard(board)
# Out:
# True
