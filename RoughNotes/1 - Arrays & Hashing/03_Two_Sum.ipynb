# %% [markdown]
# # Two Sum (LeetCode 1)

# %% [markdown]
# ## Notes

# %%
nums = [3,4,5,6]
target = 7

# %%
def twoSum(nums: list[int], target: int):
        seen = {}
        for i, num in enumerate(nums):

            complement = target - num

            if complement in seen:
                return [seen[complement], i]
            
            seen[num] = i

# %%
class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        seen = {}
        for i, num in enumerate(nums):

            complement = target - num

            if complement in seen:
                return [seen[complement], i]
            
            seen[num] = i

# %%
twoSum(nums,target)
# Out:
# 3
# Complement: 4
# Seen: {}
# 4
# Complement: 3
# Seen: {3: 0}
# [0, 1]

# %%
twoSum(nums = [4,5,6], target = 10)
# Out:
# 4
# Complement: 6
# Seen: {}
# 5
# Complement: 5
# Seen: {4: 0}
# 6
# Complement: 4
# Seen: {4: 0, 5: 1}
# [0, 2]

# %%
twoSum(nums = [5,5], target = 10)
# Out:
# 5
# Complement: 5
# Seen: {}
# 5
# Complement: 5
# Seen: {5: 0}
# [0, 1]
