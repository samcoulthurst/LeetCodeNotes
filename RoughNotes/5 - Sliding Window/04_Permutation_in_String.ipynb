# %% [markdown]
# # Permutation in String (LeetCode 567)

# %% [markdown]
# ## Notes

# %%
s1 = "abc"
s2 = "lecabee"

# %%
s1="hello"
s2="ooolleoooleh"

# %%
def checkInclusion(s1,s2):
    if len(s1) > len(s2):
        return False
    else:
        biggest = s2
        smallest = s1
    len_smallest = len(smallest)
    len_biggest = len(biggest)
    
    for i in range(len_biggest-len_smallest+1):
        window = biggest[i:i+len_smallest]
        print(i, window)
        if strToHash(window) == strToHash(smallest):
            return True
    return False

# %%
def checkInclusion(s1,s2):
    if len(s1) > len(s2):
        biggest = s1
        smallest = s2
    else:
        biggest = s2
        smallest = s1
    len_smallest = len(smallest)
    len_biggest = len(biggest)
    
    for i in range(len_biggest-len_smallest+1):
        window = biggest[i:i+len_smallest]
        print(i, window)
        if strToHash(window) == strToHash(smallest):
            return True
    return False

# %%
checkInclusion(s1,s2)
# Out:
# 0 oooll
# 1 oolle
# 2 olleo
# 3 lleoo
# 4 leooo
# 5 eoool
# 6 ooole
# 7 ooleh
# False

# %%
def strToHash(s):
    hash = {}
    for letter in s:
        hash[letter] = hash.get(letter,0) + 1

    return hash

# %%
strToHash(s2)
# Out:
# {'o': 6, 'l': 3, 'e': 2, 'h': 1}
